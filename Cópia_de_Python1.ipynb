# %% [markdown]
# <a href="https://colab.research.google.com/github/Santos421/Santos421/blob/main/C%C3%B3pia_de_Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Olá mundo"
# Out:
# 'Olá mundo'

# %%
segundos_do_dia = 24 * 60 *60
segundos_do_dia
# Out:
# 86400

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt

cores = 'rgbcmyk'
label = ['red','green','blue','cyan','magenta','yellow','black']
#   inpt' não suportado para edição de jupyterBook, comente e tire os comentários comforme indicado para execuçãono Colab
# n +int( input('Entre com um número inteiro: ')) # Tire o cometário
n = 12
                                           # Comente
cor = n % len(cores)

x = 200 + np.random.randn(100)
plt.plot(x,color=cores[cor])

plt.title(label[cor].upper(),fontsize=14)
plt.show()
